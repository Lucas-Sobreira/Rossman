# %% [markdown]
# <font color='yellow'><h1>Deploy do Modelo</h1></font>

# %%
from IPython.display import Image

PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS_Producao\\images\\deploy_modelo.png'
Image(filename= PATH, width=750, height=380)

# %% [markdown]
# ## <font color='orange'>Objetivo</font>
# <p><h3>Tornar as Predições do Modelo acessível para qualquer consumidor</h3></p>

# %% [markdown]
# ## <font color='orange'>Termos mais Comuns</font>
#
# <h5>
# <ul><b>1. API</b> → Aplication Programming Interface;</ul>
# <ul><b>2. Request</b> → Requisição/Chamada;</ul>
# <ul><b>3. Endpoint</b> → URL/Porta da API;</ul>
# <ul><b>4. Deploy</b> → Inplementação;</ul>
# <ul><b>5. Ambiente local</b> → Seu computador;</ul>
# <ul><b>6. Ambiente de Produção</b> → Servidores na Nuvem que fornecem um Serviço/Dados;</ul>
# <ul><b>7. Ambiente de Desenvolvimento</b> → Uma cópia do Ambiente de Produção na Nuvem;</ul>
# </h4>

# %% [markdown]
# ## <font color='orange'>A Arquitetura de Produção</font>

# %%
PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS_Producao\\images\\arquitetura_producao.png'
Image(filename= PATH, width=750, height=380)

# %% [markdown]
# ## <font color='orange'>Lista de Tarefas</font>

# %% [markdown]
# <h5>
# <ul>1. Criar uma Classe com as Limpezas, Transformações e Encoding <b>(Rossmann.py)</b>;</ul>
# <ul>2. Criar uma API <b>(Handler.py)</b>;</ul>
# <ul>3. Criar um Script para testar a API;</ul>
# <h5>
