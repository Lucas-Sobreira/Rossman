# %% [markdown]
# <h1>Passo 06: <font color='yellow'>Seleção de Atributos</font></h1>

# %% [markdown]
# ## Update do Progresso do Projeto Rossman

# %%
from IPython.display import Image

PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS_Producao\\images\\data_preparation.png'
Image(filename= PATH, width=800, height=350)

# %% [markdown]
# ## Teoria

# %% [markdown]
# <ul>
#     <li><h4>A explicação mais simples sobre um fenômeno observado, deveria prevalecer sobre explicações mais complexas;</h4></li>
#     <li><h4>De sempre Preferência para o <font color='orange'>Mais Simples</font>;</h4></li>
#     <li><h4>Remover <font color='orange'>Variáveis Colineares</font>, variáveis que explicam a mesma parte do fenômeno;</h4></li>
# </ul>

# %% [markdown]
# ### Exemplo de Variáveis Colineares

# %%
PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS_Producao\\images\\variaveis_colineares.png'
Image(filename= PATH, width=700, height=350)

# %% [markdown]
# ### Os tipos de <font color='orange'>Seleção de Variáveis</font>

# %% [markdown]
# #### Seleção <font color='orange'>Univariada</font> (Filter Methods)

# %% [markdown]
# <h4><font color='yellow'>Relevância</font></h4>
#
# Quanto que cada variável explica a respeito do fenomêno?

# %%
PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS_Producao\\images\\relevancia.png'
Image(filename= PATH, width=800, height=250)

# %% [markdown]
# <h4>Para fazer isso, utilizamos o <font color='orange'>Coeficiente de Correlação!</font></h4>

# %%
PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS_Producao\\images\\correlacao.png'
Image(filename= PATH, width=600, height=450)

# %%
PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS_Producao\\images\\corr_resumo.png'
Image(filename= PATH, width=800, height=400)

# %% [markdown]
# ##### <h5>
# <u><font color='yellow'>Vantagens:</font></u>
#     <ol>
#         <li>Método Simples;</li>
#         <li>Método Rápido;</li>
#         <li>Fácil Entendimento;</li>
#     </ol>
#
# <u><font color='yellow'>Desvantagens:</font></u>
#     <ol>
#         <li>Não considera a influência entre as variáveis;</li>
#     </ol>
#
# <u><font color='orange'>Exemplo:</font></u>
#     <ol>
#         <li>Variável 01 <> Vendas => <font color='Blue'>CORRELAÇÃO FRACA.</font></li>
#         <li>Variável 01 + Variável 07 <> Vendas => <font color='red'>CORRELAÇÃO FORTE.</font></li>
#     </ol>
# </h5>

# %% [markdown]
# #### Seleção por <font color='orange'>Importância</font> (Embedded Methods)

# %% [markdown]
# <h5>
# <ol>
#     <li><font color='orange'>Random Forest</font></li>
#     <li><font color='orange'>Lasso Regression</font></li>
#     <li><font color='orange'>Ridge Regression</font></li>
# </ol>
# </h5>

# %% [markdown]
# ##### <h4>1. <font color='orange'>Random Forest</font></h4>

# %%
PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS_Producao\\images\\random_forest.png'
Image(filename= PATH, width=600, height=450)

# %% [markdown]
# ##### <h4>2. <font color='orange'>Lasso e Ridge Regression</font></h4>

# %%
PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS_Producao\\images\\lasso&ridge_regression.png'
Image(filename= PATH, width=600, height=450)

# %% [markdown]
# #### Seleção por <font color='orange'>Subset</font> (Wrapper Methods)

# %%
PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS_Producao\\images\\subset.png'
Image(filename= PATH, width=600, height=400)

# %% [markdown]
# ### Como funciona o <font color='orange'>Boruta</font>

# %%
PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS_Producao\\images\\boruta.png'
Image(filename= PATH, width=700, height=450)
