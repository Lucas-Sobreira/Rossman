# %% [markdown]
# <h1>Passo 08: <font color='yellow'>Fine Tuning</font></h1>

# %% [markdown]
# ## <font color='orange'>Update do Progresso do Projeto Rossman</font>

# %%
from IPython.display import Image

PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS_Producao\\images\\Fine_Tuning.png'
Image(filename= PATH, width=800, height=400)

# %% [markdown]
# # <font color='yellow'>Hyperparameter Fine Tuning</font>

# %% [markdown]
# <h3>"Encontrar o conjunto de parâmetros que maximiza o aprendizado do modelo."</h3>

# %% [markdown]
# ## <font color='orange'>As 3 estratégias do Fine Tuning</font>

# %% [markdown]
# ### <font color='yellow'>1. Random Search</font>

# %% [markdown]
# <h4>Define valores para cada um dos hiperparâmetros aleatoriamente.</h4>

# %%
PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS_Producao\\images\\Random_Search.png'
Image(filename= PATH, width=700, height=450)

# %% [markdown]
# ### <font color='yellow'>2. Grid Search</font>

# %% [markdown]
# <h4>Define todas as combinações possíveis de valores que os hiperparâmetros podem assumir.</h4>

# %%
PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS_Producao\\images\\Grid_Search.png'
Image(filename= PATH, width=650, height=350)

# %% [markdown]
# ### <font color='yellow'>3. Bayesian Search</font>

# %% [markdown]
# <h4>Define os valores para os hiperparâmetros seguindo a teoria de Bayes.</h4>

# %%
PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS_Producao\\images\\Bayesian_Search.png'
Image(filename= PATH, width=500, height=350)

# %% [markdown]
# ## <font color='orange'>Vantagens e Desvantagens</font>

# %% [markdown]
# ### <font color='yellow'>1. Random Search</font>

# %% [markdown]
# <ol>
#     <li><h4>Rápido e Baixo Custo.</h4></li>
#     <li><h4>Define os valores Aleatoriamente.</h4></li>
# </ol>

# %% [markdown]
# ### <font color='yellow'>2. Grid Search</font>

# %% [markdown]
# <ol>
#     <li><h4>Define os verdadeiros valores que maximizam o aprendizado do modelo.</h4></li>
#     <li><h4>Muito Muito Muito DEMORADO, ALTISSIMO CUSTO.</h4></li>
# </ol>

# %% [markdown]
# ### <font color='yellow'>3. Baeysian Search</font>

# %% [markdown]
# <ol>
#     <li><h4>Define os valores para os hiperparâmetros baseado em aprendizados passados.</h4></li>
#     <li><h4>Mais rápido que o Grid Search e Mais Lento que o Random Search.</h4></li>
# </ol>
