# %% [markdown]
# <font color='orange'><h1>Entendendo o problema de negócio</h1></font>

# %% [markdown]
# <font color='yellow'><h2>10 passos de um projeto de Ciência de Dados</h2></font>
#
# 1. Descrição dos Dados;
# 2. Feature Engineering;
# 3. Filtragem de Variáveis;
# 4. Análise Exploratória de Dados (EDA);
# 5. Preparação dos Dados;
# 6. Seleção de Variáveis com Algoritmo;
# 7. Modelos de Machine Learning;
# 8. Hyperparameter Fine Tuning;
# 9. Interpretação e Tradução do Erro;
# 10. Deploy do Modelo em Produção;

# %%
from IPython.display import Image

PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS em Producao\\images\\estrutura_treinamento.jpg'
Image(filename= PATH, width=1100, height=300)

# %% [markdown]
# <font color='yellow'><h2>Entendendo o problema de negócio em 4 perguntas. </h2></font>

# %% [markdown]
# O CFO da empresa fez uma reunião com todos os Gerentes de Loja e pediu para que cada um deles trouxesse uma previsão diária das próximas 6 semanas de vendas.
#
# Depois dessa reunião, todos os Gerentes entraram em contato com você, requisitando uma previsão de vendas em sua loja.

# %% [markdown]
# <ol>
#     <font color='DeepSkyBlue'><li>Entender: A motivação</li></font>
#     <ul>
#         <li>Qual o contexto?</li>
#     </ul>
#     <p></p>
#     <font color='DeepSkyBlue'><li>Entender: A causa raiz do Problema</li></font>
#     <ul>
#         <li>Porque fazer uma Previsão de venda?</li>
#     </ul>
#     <p></p>
#     <font color='DeepSkyBlue'><li>Entender: Quem é o Dono do Problema</li></font>
#     <ul>
#         <li>Quem será o Stackholder?</li>
#     </ul>
#     <p></p>
#     <font color='DeepSkyBlue'><li>Entender: O Formato da Solução</li></font>
#     <ul>
#         <li>Qual o formato da solução?</li>
#         <ul>
#             <li>Granularidade;</li>
#             <li>TIpo do Problema;</li>
#             <li>Potenciais Métodos;</li>
#             <li>Formato da Entrega;</li>
#         </ul>
#     </ul>
# </ol>

# %% [markdown]
# <font color='yellow'><h2>Entendendo um pouco mais sobre o problema</h2></font>

# %% [markdown]
# <ol>
#     <font color='DeepSkyBlue'><li>A motivação:</li></font>
#     <ul>
#         <li>O CFO requisitou essa solução durante uma reunião de resultados mensais.</li>
#     </ul>
#     <p></p>
#     <font color='DeepSkyBlue'><li>A causa raiz do Problema:</li></font>
#     <ul>
#         <li>Investimento em Reforma das Lojas:</li>
#     </ul>
#     <p></p>
#     <font color='DeepSkyBlue'><li>Quem é o Dono do Problema:</li></font>
#     <ul>
#         <li>O CFO</li>
#     </ul>
#     <p></p>
#     <font color='DeepSkyBlue'><li>O Formato da Solução:</li></font>
#     <ul>
#         <li>Vendas diárias em R$, nas próximas 6 semanas;</li>
#         <li>Problema de Predição;</li>
#         <li>Time Series, Regressão e Neural Networks;</li>
#         <li>Predições que podem ser acessadas via celular;</li>
#     </ul>
# </ol>

# %% [markdown]
# <font color='orange'><h1>Método Crips</h1></font>

# %% [markdown]
# - <h3><font color='orange'>CR</font>oss-<font color='orange'>I</font>ndustry <font color='orange'>P</font>rocess - <font color='orange'>D</font>ata <font color='orange'>S</font>cience;</h3>
# - <h3>Método Cíclico de Desenvolvimento;</h3>

# %% [markdown]
# - 1 Ciclo CRIPS completo:
#     - 1 Versão End-to-End da Solução;
#     - Velocidade na Entrega de Valor;
#     - Mapeamento de todos os possíveis problemas;

# %%
PATH = 'D:\\Backup\\Comunidade DS\\Cursos\\DS em Producao\\images\\Crisp.png'
Image(filename= PATH, width=800, height=400)

# %% [markdown]
# <h4>
# <ul>
#     <font color='orange'>Questão de Negócio</font>
#     <ul>
#         - Qual é o valor das vendas de cada loja nas próximas 6 semanas?
#     </ul>
# </ul>
#
# <ul>
#     <font color='orange'>Entendimento do Negócio</font>
#     <ul>
#         <font color='yellow'>- Qual a Motivação</font>
#         <ul>
#             - A previsão de vendas foi requisitada pelo CFO em uma reunião mensal sobre os resultados das lojas;
#         </ul>
#     </ul>
#     <ul>
#         <font color='yellow'>- Qual a Causa Raiz do Problema?</font>
#         <ul>
#             - Deficuldade em determinar o valor do investimento para Reformas de cada loja;
#         </ul>
#     </ul>
#     <ul>
#         <font color='yellow'>- Quem é o Dono do Problema?</font>
#         <ul>
#             - Diretor Financeiro (CFO) da Rossman;
#         </ul>
#     </ul>
#     <ul>
#         <font color='yellow'>- Qual o Formato da Soluçaõ?</font>
#         <ul>
#             - <font color='red'><b>Granularidade:</b></font> Previsão de Vendas por Dia e Loja para as próximas 6 semanas, 42 dias;
#         </ul>
#         <ul>
#             - <font color='red'><b>Tipo do Problema:</b></font> Previsão de Vendas;
#         </ul>
#         <ul>
#             - <font color='red'><b>Potenciais Métodos:</b></font> Séries Temporais, Regressão Linear;
#         </ul>
#         <ul>
#             - <font color='red'><b>Formato da Entrega:</b></font>
#             <ul>
#                 1) O valor total das vendas no final de cada loja no final da 6 semana;
#             </ul>
#             <ul>
#                 2) Como essas vendas acontecem diariamente;
#             </ul>
#         </ul>
#     </ul>
# </ul>
